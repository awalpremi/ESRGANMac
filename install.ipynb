# %%
# Install and setup necessary libraries
# !pip install basicsr facexlib gfpgan tqdm opencv-python
# !pip install -r https://raw.githubusercontent.com/xinntao/Real-ESRGAN/master/requirements.txt

# Clone the Real-ESRGAN repository
import os
if not os.path.exists("Real-ESRGAN"):
    # !git clone https://github.com/xinntao/Real-ESRGAN.git

# Navigate into the Real-ESRGAN directory and install the package
# %cd Real-ESRGAN
# !python setup.py develop
# Out:
# ...
# Cloning into 'Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Total 759 (delta 0), reused 0 (delta 0), pack-reused 759 (from 1)
# Receiving objects: 100% (759/759), 5.39 MiB | 10.41 MiB/s, done.
# Resolving deltas: 100% (408/408), done.
# /Users/awal/Desktop/LLC/Applis/Upscalers/Real-ESRGAN
# /opt/homebrew/Caskroom/miniforge/base/envs/music/lib/python3.9/site-packages/setuptools/__init__.py:81: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# ...
